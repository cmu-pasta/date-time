# %% [markdown]
# # Post-processing the Data.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./data/bugs_analysis_base.tsv', sep='\t')

# Filter out rows that are not relevant
df = df[(df['Training?'] == True) | (df['Testing?'] == True) | (df['Set 3?'] == True)]
print("Total number of datapoints: ", len(df))

df = df[df['Skipped?'] != True]
print("Total number of datapoints: ", len(df))

df = df[df['False pos?'] != True]
print("Total number of datapoints: ", len(df))

# Drop irrelevant columns
df = df.drop(columns=['Make Benchmark?', 'Associated Benchmark', 'Rater', 'Training?', 'Testing?', 'Set 3?', 'Real Testing?', 'Description', 'Comments', 'Skipped?', 'False pos?']) 
df.head()
# Out:
# Total number of datapoints:  261
# Total number of datapoints:  252
# Total number of datapoints:  151
#               Owner          Project  \
# 0     python-poetry          tomlkit
# 1  frictionlessdata  frictionless-py
# 2         sdispater         pendulum
# 3        googleapis   python-storage
# 4        googleapis   python-logging
#
#                                                Title  \
# 0  datetime.utcnow and datetime.utcfromtimestamp ...
# 1                       SpssParser ignores timezones
# 2  Deepcopy of Month-based Duration produces a di...
# 3  `DeprecationWarning` warning in build log for ...
# 4  `DeprecationWarning` warning in build log for ...
#
#                                                 Link  \
# 0  https://github.com/python-poetry/tomlkit/issue...
# 1  https://github.com/frictionlessdata/frictionle...
# 2   https://github.com/sdispater/pendulum/issues/714
# 3  https://github.com/googleapis/python-storage/i...
# 4  https://github.com/googleapis/python-logging/i...
#
#                                             Fix Link   Stars   TF-IDFs  \
# 0  https://github.com/python-poetry/tomlkit/commi...   643.0  1.312623
# 1  https://github.com/frictionlessdata/frictionle...   683.0  1.270077
# 2  https://github.com/sdispater/pendulum/commit/9...  6109.0  1.191295
# 3  https://github.com/googleapis/python-storage/c...   420.0  1.176351
# 4  https://github.com/googleapis/python-logging/p...   119.0  1.167279
#
#       Size  Datetime  Arrow  ...  Erroneous Computation 1  \
# 0   1001.0       1.0    0.0  ...    Datetime Construction
# 1   1279.0       1.0    0.0  ...    Datetime Construction
# 2   1014.0       1.0    0.0  ...       Delta Construction
# 3  10349.0       1.0    0.0  ...      Datetime Comparison
# 4   2673.0       1.0    0.0  ...    Datetime Construction
#
#             Erroneous Computation 2 Erroneous Computation 3 Obscurity  Impact  \
# 0                               NaN                     NaN       Low     Low
# 1  String Parsing/Formatting (data)                     NaN       Low  Medium
# 2                               NaN                     NaN    Medium  Medium
# 3                               NaN                     NaN       Low     Low
# 4                               NaN                     NaN       Low     Low
#
#     # LOC Logic Needed             Bug Pattern 1 Bug Pattern 2 Bug Pattern 3
# 0     Low          Low  Outdated/Deprecated APIs           NaN           NaN
# 1  Medium         High        Dropping Timezones           NaN           NaN
# 2  Medium          Low    Unintuitive Arithmetic           NaN           NaN
# 3     Low          Low  Outdated/Deprecated APIs           NaN           NaN
# 4     Low          Low  Outdated/Deprecated APIs           NaN           NaN
#
# [5 rows x 23 columns]

# %%
#Write it to a file
df.to_csv('./data/bugs_analysis_base_processed.tsv', sep='\t', index=False)

# %%
# Code to merge the Erroneous computations

df = pd.read_csv('./data/bugs_analysis_base_processed.tsv', sep='\t')
print("Total number of datapoints: ", len(df))

affected_computations = """Timestamp/Hash Construction
Datetime Arithmetic
Datetime Comparison
Datetime Construction
Datetime Equality
Delta Arithmetic
Delta Comparison
Delta Construction
Querying Datetime Components
Replacing/Rounding Datetime Components
String Parsing/Formatting (humanized)
String Parsing/Formatting (data)
Timezone Conversions
Timezone Equality""".split("\n")

target_computations = """Timestamp/Hash Construction
Datetime Arithmetic
Datetime Construction
Delta Arithmetic
Delta Construction
Querying Datetime Components
Replacing/Rounding Datetime Components
String Parsing/Formatting
Timezone Comparison and Conversions""".split("\n")

for index, value in df['Category 1'].items():
    print(f"Index: {index}, Value: {value}")

    if (value == "Date"):
        df.at[index, 'Category 1'] = "Calendar Date"
    if (value == "Timezone"):
        df.at[index, 'Category 1'] = "Time Zone"
    if (value == "Deprecated"):
        df.at[index, 'Category 1'] = "Other"

for index, value in df['Category 2'].items():
    print(f"Index: {index}, Value: {value}")

    if (value == "Date"):
        df.at[index, 'Category 2'] = "Calendar Date"
    if (value == "Timezone"):
        df.at[index, 'Category 2'] = "Time Zone"
    if (value == "Deprecated"):
        df.at[index, 'Category 2'] = "Other"

for index, value in df['Erroneous Computation 1'].items():
    print(f"Index: {index}, Value: {value}")
    if (value == "Timestamp/Hash Construction"):
        df.at[index, 'Erroneous Computation 1'] = "Timestamp API"

    if (value == "String Parsing/Formatting (humanized)") or (value == "String Parsing/Formatting (data)"):
        df.at[index, 'Erroneous Computation 1'] = "Parsing/Formatting"

    if (value == "Datetime Comparison") or (value == "Datetime Equality") or (value == "Datetime Arithmetic"):
        df.at[index, 'Erroneous Computation 1'] = "Datetime (Arithmetic)"
    
    if (value == "Datetime Construction"):
        df.at[index, 'Erroneous Computation 1'] = "Datetime (Construction)"
    
    if (value == "Delta Comparison") or (value == "Delta Arithmetic") or (value == "Delta Construction"):
        df.at[index, 'Erroneous Computation 1'] = "Delta API"
    
    if (value == "Timezone Conversions") or (value == "Timezone Equality"):
        df.at[index, 'Erroneous Computation 1'] = "Time Zone Manipulation"

    if (value == "Querying Datetime Components") or (value == "Replacing/Rounding Datetime Components"):
        df.at[index, 'Erroneous Computation 1'] = "Datetime (Projection)"

for index, value in df['Erroneous Computation 2'].items():
    print(f"Index: {index}, Value: {value}")
    if (value == "Timestamp/Hash Construction"):
        df.at[index, 'Erroneous Computation 2'] = "Timestamp API"

    if (value == "String Parsing/Formatting (humanized)") or (value == "String Parsing/Formatting (data)"):
        df.at[index, 'Erroneous Computation 2'] = "Parsing/Formatting"

    if (value == "Datetime Comparison") or (value == "Datetime Equality") or (value == "Datetime Arithmetic"):
        df.at[index, 'Erroneous Computation 2'] = "Datetime (Arithmetic)"
    
    if (value == "Datetime Construction"):
        df.at[index, 'Erroneous Computation 2'] = "Datetime (Construction)"
    
    if (value == "Delta Comparison") or (value == "Delta Arithmetic") or (value == "Delta Construction"):
        df.at[index, 'Erroneous Computation 2'] = "Delta API"
    
    if (value == "Timezone Conversions") or (value == "Timezone Equality"):
        df.at[index, 'Erroneous Computation 2'] = "Time Zone Manipulation"

    if (value == "Querying Datetime Components") or (value == "Replacing/Rounding Datetime Components"):
        df.at[index, 'Erroneous Computation 2'] = "Datetime (Projection)"

for index, value in df['Erroneous Computation 3'].items():
    print(f"Index: {index}, Value: {value}")
    if (value == "Timestamp/Hash Construction"):
        df.at[index, 'Erroneous Computation 3'] = "Timestamp API"

    if (value == "String Parsing/Formatting (humanized)") or (value == "String Parsing/Formatting (data)"):
        df.at[index, 'Erroneous Computation 3'] = "Parsing/Formatting"

    if (value == "Datetime Comparison") or (value == "Datetime Equality") or (value == "Datetime Arithmetic"):
        df.at[index, 'Erroneous Computation 3'] = "Datetime (Arithmetic)"
    
    if (value == "Datetime Construction"):
        df.at[index, 'Erroneous Computation 3'] = "Datetime (Construction)"
    
    if (value == "Delta Comparison") or (value == "Delta Arithmetic") or (value == "Delta Construction"):
        df.at[index, 'Erroneous Computation 3'] = "Delta API"
    
    if (value == "Timezone Conversions") or (value == "Timezone Equality"):
        df.at[index, 'Erroneous Computation 3'] = "Time Zone Manipulation"

    if (value == "Querying Datetime Components") or (value == "Replacing/Rounding Datetime Components"):
        df.at[index, 'Erroneous Computation 3'] = "Datetime (Projection)"



for index, value in df['Bug Pattern 1'].items():
    print(f"Index: {index}, Value: {value}")
    if (value == "Compatibility Issues"):
        df.at[index, 'Bug Pattern 1'] = "General"
    if (value == "Incorrect API usage"):
        df.at[index, 'Bug Pattern 1'] = "Incorrect API Usage"
    if (value == "Comparing Timezones"):
        df.at[index, 'Bug Pattern 1'] = "Comparing Time Zones"
    if (value == "Creating time in unspecified fold"):
        df.at[index, 'Bug Pattern 1'] = "Unspecified Fold"
    if (value == "Dropping Timezones"):
        df.at[index, 'Bug Pattern 1'] = "Dropping Time Zone Information"

for index, value in df['Bug Pattern 2'].items():
    print(f"Index: {index}, Value: {value}")
    if (value == "Compatibility Issues"):
        df.at[index, 'Bug Pattern 2'] = "General"
    if (value == "Incorrect API usage"):
        df.at[index, 'Bug Pattern 2'] = "Incorrect API Usage"
    if (value == "Comparing Timezones"):
        df.at[index, 'Bug Pattern 2'] = "Comparing Time Zones"
    if (value == "Creating time in unspecified fold"):
        df.at[index, 'Bug Pattern 2'] = "Unspecified Fold"
    if (value == "Dropping Timezones"):
        df.at[index, 'Bug Pattern 2'] = "Dropping Time Zone Information"

for index, value in df['Bug Pattern 3'].items():
    print(f"Index: {index}, Value: {value}")
    if (value == "Compatibility Issues"):
        df.at[index, 'Bug Pattern 3'] = "General"
    if (value == "Incorrect API usage"):
        df.at[index, 'Bug Pattern 3'] = "Incorrect API Usage"
    if (value == "Comparing Timezones"):
        df.at[index, 'Bug Pattern 3'] = "Comparing Time Zones"
    if (value == "Creating time in unspecified fold"):
        df.at[index, 'Bug Pattern 3'] = "Unspecified Fold"
    if (value == "Dropping Timezones"):
        df.at[index, 'Bug Pattern 3'] = "Dropping Time Zone Information"

df.head()
# Out:
# Total number of datapoints:  151
# Index: 0, Value: Deprecated
# Index: 1, Value: Timezone
# Index: 2, Value: Duration
# Index: 3, Value: Deprecated
# Index: 4, Value: Deprecated
# Index: 22, Value: Timezone Conversions
# Index: 23, Value: Datetime Arithmetic
# Index: 24, Value: Timezone Conversions
# Index: 25, Value: String Parsing/Formatting (data)
# Index: 26, Value: Datetime Arithmetic
# Index: 27, Value: Timezone Conversions
# Index: 28, Value: Timestamp/Hash Construction
# Index: 29, Value: Datetime Construction
# Index: 30, Value: String Parsing/Formatting (data)
# Index: 31, Value: Datetime Construction
# Index: 32, Value: Delta Comparison
# Index: 33, Value: String Parsing/Formatting (data)
# Index: 34, Value: Datetime Construction
# Index: 35, Value: Timezone Conversions
# Index: 36, Value: Datetime Construction
# Index: 37, Value: Timezone Conversions
# Index: 38, Value: Replacing/Rounding Datetime Components
# Index: 39, Value: String Parsing/Formatting (data)
# Index: 40, Value: String Parsing/Formatting (data)
# Index: 41, Value: Datetime Construction
# Index: 42, Value: Datetime Construction
# Index: 43, Value: String Parsing/Formatting (data)
# Index: 44, Value: Timezone Conversions
# Index: 45, Value: Datetime Construction
# Index: 46, Value: Timezone Conversions
# Index: 47, Value: Datetime Construction
# Index: 48, Value: Datetime Construction
# Index: 49, Value: Datetime Arithmetic
# Index: 50, Value: Datetime Equality
# Index: 51, Value: Delta Construction
# Index: 52, Value: Datetime Construction
# Index: 53, Value: Datetime Arithmetic
# Index: 54, Value: Datetime Construction
# Index: 55, Value: Timestamp/Hash Construction
# Index: 56, Value: Delta Construction
# Index: 57, Value: Datetime Construction
# Index: 58, Value: Datetime Construction
# Index: 59, Value: Datetime Construction
# Index: 60, Value: Datetime Construction
# Index: 61, Value: String Parsing/Formatting (data)
# Index: 62, Value: Datetime Construction
# Index: 63, Value: Datetime Construction
# Index: 64, Value: Querying Datetime Components
# Index: 65, Value: Datetime Construction
# Index: 66, Value: Querying Datetime Components
# Index: 67, Value: Timestamp/Hash Construction
# Index: 68, Value: String Parsing/Formatting (humanized)
# Index: 69, Value: Timezone Conversions
# Index: 70, Value: Datetime Construction
# Index: 71, Value: Datetime Construction
# Index: 72, Value: Datetime Construction
# Index: 73, Value: Datetime Construction
# Index: 74, Value: String Parsing/Formatting (humanized)
# Index: 75, Value: Timestamp/Hash Construction
# Index: 76, Value: Datetime Construction
# Index: 77, Value: Datetime Arithmetic
# Index: 78, Value: String Parsing/Formatting (data)
# Index: 79, Value: Datetime Construction
# Index: 80, Value: Replacing/Rounding Datetime Components
# Index: 81, Value: Datetime Construction
# Index: 82, Value: Timezone Equality
# Index: 83, Value: String Parsing/Formatting (data)
# Index: 84, Value: Datetime Construction
# Index: 85, Value: Querying Datetime Components
# Index: 86, Value: String Parsing/Formatting (data)
# Index: 87, Value: String Parsing/Formatting (humanized)
# Index: 88, Value: String Parsing/Formatting (data)
# Index: 89, Value: Datetime Construction
# Index: 90, Value: Timezone Equality
# Index: 91, Value: Timestamp/Hash Construction
# Index: 92, Value: Datetime Arithmetic
# Index: 93, Value: Datetime Construction
# Index: 94, Value: Datetime Arithmetic
# Index: 95, Value: Datetime Comparison
# Index: 96, Value: Datetime Construction
# Index: 97, Value: Datetime Construction
# Index: 98, Value: Datetime Construction
# Index: 99, Value: Datetime Construction
# Index: 100, Value: Datetime Equality
# Index: 101, Value: Datetime Construction
# Index: 102, Value: Datetime Construction
# Index: 103, Value: Delta Comparison
# Index: 104, Value: Timezone Conversions
# Index: 105, Value: String Parsing/Formatting (data)
# Index: 106, Value: Datetime Construction
# Index: 107, Value: Replacing/Rounding Datetime Components
# Index: 108, Value: Timezone Conversions
# Index: 109, Value: Timezone Conversions
# Index: 110, Value: Datetime Equality
# Index: 111, Value: Timestamp/Hash Construction
# Index: 112, Value: String Parsing/Formatting (humanized)
# Index: 113, Value: Delta Construction
# Index: 114, Value: Datetime Arithmetic
# Index: 115, Value: Datetime Construction
# Index: 116, Value: String Parsing/Formatting (data)
# Index: 117, Value: Timezone Conversions
# Index: 118, Value: Datetime Construction
# Index: 119, Value: Timezone Conversions
# Index: 120, Value: Datetime Construction
# Index: 121, Value: Datetime Construction
# Index: 122, Value: String Parsing/Formatting (data)
# Index: 123, Value: String Parsing/Formatting (data)
# Index: 124, Value: Timezone Conversions
# Index: 125, Value: Timestamp/Hash Construction
# Index: 126, Value: Replacing/Rounding Datetime Components
# Index: 127, Value: Timezone Conversions
# Index: 128, Value: String Parsing/Formatting (data)
# Index: 129, Value: Timezone Conversions
# Index: 130, Value: String Parsing/Formatting (data)
# Index: 131, Value: Querying Datetime Components
# Index: 132, Value: String Parsing/Formatting (data)
# Index: 133, Value: String Parsing/Formatting (data)
# Index: 134, Value: String Parsing/Formatting (data)
# Index: 135, Value: Datetime Construction
# Index: 136, Value: Datetime Construction
# Index: 137, Value: String Parsing/Formatting (data)
# Index: 138, Value: Datetime Construction
# Index: 139, Value: Datetime Construction
# Index: 140, Value: Querying Datetime Components
# Index: 141, Value: String Parsing/Formatting (humanized)
# Index: 142, Value: Datetime Construction
# Index: 143, Value: Datetime Construction
# Index: 144, Value: Datetime Construction
# Index: 145, Value: String Parsing/Formatting (data)
# Index: 146, Value: String Parsing/Formatting (data)
# Index: 147, Value: String Parsing/Formatting (data)
# Index: 148, Value: Datetime Construction
# Index: 149, Value: Delta Arithmetic
# Index: 150, Value: Timezone Conversions
# Index: 0, Value: nan
# Index: 1, Value: String Parsing/Formatting (data)
# Index: 2, Value: nan
# Index: 3, Value: nan
# Index: 4, Value: nan
# Index: 5, Value: nan
# Index: 6, Value: nan
# Index: 7, Value: Datetime Construction
# Index: 8, Value: nan
# Index: 9, Value: Datetime Construction
# Index: 10, Value: nan
# Index: 11, Value: nan
# Index: 12, Value: nan
# Index: 13, Value: Datetime Construction
# Index: 14, Value: nan
# Index: 15, Value: nan
# Index: 16, Value: nan
# Index: 17, Value: nan
# Index: 18, Value: Replacing/Rounding Datetime Components
# Index: 19, Value: nan
# Index: 20, Value: nan
# Index: 21, Value: nan
# Index: 22, Value: Datetime Construction
# Index: 23, Value: nan
# Index: 24, Value: String Parsing/Formatting (data)
# Index: 25, Value: Datetime Construction
# Index: 26, Value: nan
# Index: 27, Value: Timestamp/Hash Construction
# Index: 28, Value: Datetime Construction
# Index: 29, Value: nan
# Index: 23, Value: Unintuitive Arithmetic
# Index: 24, Value: Dropping Timezones
# Index: 25, Value: Compatibility Issues
# Index: 26, Value: Unintuitive Arithmetic
# Index: 27, Value: Dropping Timezones
# Index: 28, Value: Using Naïve Datetime Incorrectly
# Index: 29, Value: Outdated/Deprecated APIs
# Index: 30, Value: Dropping Timezones
# Index: 31, Value: Outdated/Deprecated APIs
# Index: 32, Value: Outdated/Deprecated APIs
# Index: 33, Value: Precision of Representation
# Index: 34, Value: Compatibility Issues
# Index: 35, Value: Using Naïve Datetime Incorrectly
# Index: 36, Value: Using Naïve Datetime Incorrectly
# Index: 37, Value: Using Naïve Datetime Incorrectly
# Index: 38, Value: Unintuitive Arithmetic
# Index: 39, Value: Comparing Timezones
# Index: 40, Value: Incorrect Format Assumptions
# Index: 41, Value: Using Naïve Datetime Incorrectly
# Index: 42, Value: Using Naïve Datetime Incorrectly
# Index: 43, Value: Compatibility Issues
# Index: 44, Value: Outdated/Deprecated APIs
# Index: 45, Value: Using Naïve Datetime Incorrectly
# Index: 46, Value: Outdated/Deprecated APIs
# Index: 47, Value: Dropping Timezones
# Index: 48, Value: Using Naïve Datetime Incorrectly
# Index: 49, Value: Unintuitive Arithmetic
# Index: 50, Value: Comparing Timezones
# Index: 51, Value: Incorrect Format Assumptions
# Index: 52, Value: Unintuitive Arithmetic
# Index: 53, Value: Unintuitive Arithmetic
# Index: 54, Value: Unintuitive Arithmetic
# Index: 55, Value: Outdated/Deprecated APIs
# Index: 56, Value: General
# Index: 57, Value: Outdated/Deprecated APIs
# Index: 58, Value: Using Naïve Datetime Incorrectly
# Index: 59, Value: Dropping Timezones
# Index: 60, Value: Outdated/Deprecated APIs
# Index: 61, Value: Dropping Timezones
# Index: 62, Value: Using Naïve Datetime Incorrectly
# Index: 63, Value: Precision of Representation
# Index: 64, Value: Compatibility Issues
# Index: 65, Value: Outdated/Deprecated APIs
# Index: 66, Value: Compatibility Issues
# Index: 67, Value: Using Naïve Datetime Incorrectly
# Index: 68, Value: Using Naïve Datetime Incorrectly
# Index: 69, Value: Using Naïve Datetime Incorrectly
# Index: 70, Value: Precision of Representation
# Index: 71, Value: Creating time in unspecified fold
# Index: 72, Value: Using Naïve Datetime Incorrectly
# Index: 73, Value: Precision of Representation
# Index: 74, Value: Unintuitive Arithmetic
# Index: 75, Value: Unintuitive Arithmetic
# Index: 76, Value: Outdated/Deprecated APIs
# Index: 77, Value: Using Naïve Datetime Incorrectly
# Index: 78, Value: Using Naïve Datetime Incorrectly
# Index: 79, Value: Unintuitive Arithmetic
# Index: 80, Value: Using Naïve Datetime Incorrectly
# Index: 81, Value: General
# Index: 82, Value: Comparing Timezones
# Index: 83, Value: Incorrect Format Assumptions
# Index: 84, Value: Using Naïve Datetime Incorrectly
# Index: 85, Value: Incorrect Format Assumptions
# Index: 86, Value: Unintuitive Arithmetic
# Index: 87, Value: Precision of Representation
# Index: 88, Value: Precision of Representation
# Index: 89, Value: Using Naïve Datetime Incorrectly
# Index: 90, Value: Comparing Timezones
# Index: 91, Value: OOB Datetimes or Timestamps
# Index: 92, Value: Using Naïve Datetime Incorrectly
# Index: 93, Value: Using Naïve Datetime Incorrectly
# Index: 94, Value: General
# Index: 95, Value: Using Naïve Datetime Incorrectly
# Index: 96, Value: Incorrect API usage
# Index: 97, Value: Outdated/Deprecated APIs
# Index: 98, Value: Using Naïve Datetime Incorrectly
# Index: 99, Value: General
# Index: 100, Value: Comparing Timezones
# Index: 101, Value: Outdated/Deprecated APIs
# Index: 102, Value: Dropping Timezones
# Index: 103, Value: Compatibility Issues
# Index: 104, Value: Dropping Timezones
# Index: 105, Value: Precision of Representation
# Index: 106, Value: Unintuitive Arithmetic
# Index: 107, Value: Incorrect Format Assumptions
# Index: 108, Value: Compatibility Issues
# Index: 109, Value: Using Naïve Datetime Incorrectly
# Index: 110, Value: Compatibility Issues
# Index: 111, Value: Precision of Representation
# Index: 112, Value: Using Naïve Datetime Incorrectly
# Index: 113, Value: Incorrect Format Assumptions
# Index: 114, Value: Using Naïve Datetime Incorrectly
# Index: 115, Value: Precision of Representation
# Index: 116, Value: Dropping Timezones
# Index: 117, Value: Using Naïve Datetime Incorrectly
# Index: 118, Value: General
# Index: 119, Value: Using Naïve Datetime Incorrectly
# Index: 120, Value: Creating time in unspecified fold
# Index: 121, Value: Using Naïve Datetime Incorrectly
# Index: 122, Value: Precision of Representation
# Index: 123, Value: Incorrect Format Assumptions
# Index: 124, Value: Incorrect API usage
# Index: 125, Value: Dropping Timezones
# Index: 126, Value: Creating time in unspecified fold
# Index: 127, Value: Using Naïve Datetime Incorrectly
# Index: 128, Value: Dropping Timezones
# Index: 129, Value: Unintuitive Arithmetic
# Index: 130, Value: Incorrect Format Assumptions
# Index: 131, Value: Incorrect API usage
# Index: 132, Value: Incorrect Format Assumptions
# Index: 133, Value: OOB Datetimes or Timestamps
# Index: 134, Value: Incorrect Format Assumptions
# Index: 135, Value: Using Naïve Datetime Incorrectly
# Index: 136, Value: Using Naïve Datetime Incorrectly
# Index: 137, Value: Precision of Representation
# Index: 138, Value: Incorrect API usage
# Index: 139, Value: OOB Datetimes or Timestamps
# Index: 140, Value: Unintuitive Arithmetic
# Index: 141, Value: Incorrect Format Assumptions
# Index: 142, Value: Compatibility Issues
# Index: 143, Value: Using Naïve Datetime Incorrectly
# Index: 144, Value: Using Naïve Datetime Incorrectly
# Index: 145, Value: Incorrect Format Assumptions
# Index: 146, Value: Incorrect Format Assumptions
# Index: 147, Value: OOB Datetimes or Timestamps
# Index: 148, Value: Outdated/Deprecated APIs
# Index: 149, Value: Precision of Representation
# Index: 150, Value: General
# Index: 0, Value: nan
# Index: 1, Value: nan
# Index: 2, Value: nan
# Index: 3, Value: nan
# Index: 4, Value: nan
# Index: 5, Value: Dropping Timezones
# Index: 6, Value: nan
# Index: 7, Value: nan
# Index: 8, Value: nan
# Index: 9, Value: Dropping Timezones
# Index: 10, Value: nan
# Index: 11, Value: nan
# Index: 12, Value: nan
# Index: 13, Value: nan
# Index: 14, Value: nan
# Index: 15, Value: nan
# Index: 87, Value: nan
# Index: 88, Value: nan
# Index: 89, Value: nan
# Index: 90, Value: nan
# Index: 91, Value: nan
# Index: 92, Value: nan
# Index: 93, Value: nan
# Index: 94, Value: nan
# Index: 95, Value: nan
# Index: 96, Value: nan
# Index: 97, Value: nan
# Index: 98, Value: nan
# Index: 99, Value: nan
# Index: 100, Value: nan
# Index: 101, Value: nan
# Index: 102, Value: nan
# Index: 103, Value: nan
# Index: 104, Value: nan
# Index: 105, Value: nan
# Index: 106, Value: nan
# Index: 107, Value: nan
# Index: 108, Value: nan
# Index: 109, Value: nan
# Index: 110, Value: nan
# Index: 111, Value: nan
# Index: 112, Value: nan
# Index: 113, Value: nan
# Index: 114, Value: nan
# Index: 115, Value: nan
# Index: 116, Value: nan
# Index: 117, Value: nan
# Index: 118, Value: nan
# Index: 119, Value: nan
# Index: 120, Value: nan
# Index: 121, Value: nan
# Index: 122, Value: nan
# Index: 123, Value: nan
# Index: 124, Value: nan
# Index: 125, Value: nan
# Index: 126, Value: nan
# Index: 127, Value: nan
# Index: 128, Value: nan
# Index: 129, Value: nan
# Index: 130, Value: nan
# Index: 131, Value: nan
# Index: 132, Value: nan
# Index: 133, Value: nan
# Index: 134, Value: nan
# Index: 135, Value: nan
# Index: 136, Value: nan
# Index: 137, Value: nan
# Index: 138, Value: nan
# Index: 139, Value: nan
# Index: 140, Value: nan
# Index: 141, Value: nan
# Index: 142, Value: Incorrect Format Assumptions
# Index: 143, Value: nan
# Index: 144, Value: nan
# Index: 145, Value: nan
# Index: 146, Value: nan
# Index: 147, Value: nan
# Index: 148, Value: nan
# Index: 149, Value: nan
# Index: 150, Value: nan
#               Owner          Project  \
# 0     python-poetry          tomlkit
# 1  frictionlessdata  frictionless-py
# 2         sdispater         pendulum
# 3        googleapis   python-storage
# 4        googleapis   python-logging
#
#                                                Title  \
# 0  datetime.utcnow and datetime.utcfromtimestamp ...
# 1                       SpssParser ignores timezones
# 2  Deepcopy of Month-based Duration produces a di...
# 3  `DeprecationWarning` warning in build log for ...
# 4  `DeprecationWarning` warning in build log for ...
#
#                                                 Link  \
# 0  https://github.com/python-poetry/tomlkit/issue...
# 1  https://github.com/frictionlessdata/frictionle...
# 2   https://github.com/sdispater/pendulum/issues/714
# 3  https://github.com/googleapis/python-storage/i...
# 4  https://github.com/googleapis/python-logging/i...
#
#                                             Fix Link   Stars   TF-IDFs  \
# 0  https://github.com/python-poetry/tomlkit/commi...   643.0  1.312623
# 1  https://github.com/frictionlessdata/frictionle...   683.0  1.270077
# 2  https://github.com/sdispater/pendulum/commit/9...  6109.0  1.191295
# 3  https://github.com/googleapis/python-storage/c...   420.0  1.176351
# 4  https://github.com/googleapis/python-logging/p...   119.0  1.167279
#
#       Size  Datetime  Arrow  ...  Erroneous Computation 1  \
# 0   1001.0       1.0    0.0  ...  Datetime (Construction)
# 1   1279.0       1.0    0.0  ...  Datetime (Construction)
# 2   1014.0       1.0    0.0  ...                Delta API
# 3  10349.0       1.0    0.0  ...    Datetime (Arithmetic)
# 4   2673.0       1.0    0.0  ...  Datetime (Construction)
#
#   Erroneous Computation 2 Erroneous Computation 3 Obscurity  Impact   # LOC  \
# 0                     NaN                     NaN       Low     Low     Low
# 1      Parsing/Formatting                     NaN       Low  Medium  Medium
# 2                     NaN                     NaN    Medium  Medium  Medium
# 3                     NaN                     NaN       Low     Low     Low
# 4                     NaN                     NaN       Low     Low     Low
#
#   Logic Needed                   Bug Pattern 1 Bug Pattern 2 Bug Pattern 3
# 0          Low        Outdated/Deprecated APIs           NaN           NaN
# 1         High  Dropping Time Zone Information           NaN           NaN
# 2          Low          Unintuitive Arithmetic           NaN           NaN
# 3          Low        Outdated/Deprecated APIs           NaN           NaN
# 4          Low        Outdated/Deprecated APIs           NaN           NaN
#
# [5 rows x 23 columns]

# %%
# Write it to a file
df.to_csv('./data/bugs_analysis_base_processed+grouped.tsv', sep='\t', index=False)

# %%
df = pd.read_csv('./data/bugs_analysis_rater_1.tsv', sep='\t')

# Filter out rows that are not relevant
df = df[(df['Testing?'] == True)]

# Drop irrelevant columns
df = df.drop(columns=['Make Benchmark?', 'Associated Benchmark', 'Training?', 'Testing?', 'Set 3?', 'Real Testing?', 'Description', 'Comments']) 

print("Total number of datapoints: ", len(df))
df.head()
# Out:
# Total number of datapoints:  60
#               Rater  Skipped?  False pos?             Owner          Project  \
# 1    5: Peter Sasha     False       False  frictionlessdata  frictionless-py
# 3   2: Shrey Serena     False       False        googleapis   python-storage
# 10   3: Shrey Sasha     False        True         sdispater         pendulum
# 12  2: Shrey Serena     False       False        Bears-R-Us          arkouda
# 14   5: Peter Sasha     False       False          dateutil         dateutil
#
#                                                 Title  \
# 1                        SpssParser ignores timezones
# 3   `DeprecationWarning` warning in build log for ...
# 10                             DateTime.add(duration)
# 12          datetime columns in dataframe display bug
# 14                   last day of the month is wrong??
#
#                                                  Link  \
# 1   https://github.com/frictionlessdata/frictionle...
# 3   https://github.com/googleapis/python-storage/i...
# 10   https://github.com/sdispater/pendulum/issues/323
# 12  https://github.com/Bears-R-Us/arkouda/issues/2596
# 14   https://github.com/dateutil/dateutil/issues/1167
#
#                                              Fix Link   Stars   TF-IDFs  ...  \
# 1   https://github.com/frictionlessdata/frictionle...   683.0  1.270077  ...
# 3   https://github.com/googleapis/python-storage/c...   420.0  1.176351  ...
# 10  https://github.com/gridsingularity/gsy-e/pull/...  6109.0  0.996023  ...
# 12  https://github.com/stress-tess/arkouda/commit/...   228.0  0.947325  ...
# 14     https://github.com/dateutil/dateutil/pull/1168  2266.0  0.935691  ...
#
#     Erroneous Computation 1           Erroneous Computation 2  \
# 1     Datetime Construction  String Parsing/Formatting (data)
# 3     Datetime Construction                               NaN
# 10                      NaN                               NaN
# 12    Datetime Construction                               NaN
# 14      Datetime Arithmetic                               NaN
#
#     Erroneous Computation 3  Obscurity Impact   # LOC Logic Needed  \
# 1                       NaN     Medium    Low  Medium       Medium
# 3                       NaN        Low    Low     Low          Low
# 10                      NaN        NaN    NaN     NaN          NaN
# 12                      NaN     Medium    Low     Low          Low
# 14                      NaN        Low    Low  Medium       Medium
#
#                Bug Pattern 1 Bug Pattern 2 Bug Pattern 3
# 1         Dropping Timezones           NaN           NaN
# 3   Outdated/Deprecated APIs           NaN           NaN
# 10                       NaN           NaN           NaN
# 12       Incorrect API usage           NaN           NaN
# 14    Unintuitive Arithmetic           NaN           NaN
#
# [5 rows x 26 columns]

# %%
# write it to a file
df.to_csv('./data/bugs_analysis_rater_1.tsv', sep='\t', index=False)

# %%
df = pd.read_csv('./data/bugs_analysis_rater_2.tsv', sep='\t')

# Filter out rows that are not relevant
df = df[(df['Testing?'] == True)]

# Drop irrelevant columns
df = df.drop(columns=['Make Benchmark?', 'Associated Benchmark', 'Training?', 'Testing?', 'Set 3?', 'Real Testing?', 'Description', 'Comments']) 

print("Total number of datapoints: ", len(df))
df.head()
# Out:
# Total number of datapoints:  60
#               Rater  Skipped?  False pos?             Owner          Project  \
# 1    5: Peter Sasha     False       False  frictionlessdata  frictionless-py
# 3   2: Shrey Serena     False       False        googleapis   python-storage
# 10   3: Shrey Sasha     False        True         sdispater         pendulum
# 12  2: Shrey Serena     False        True        Bears-R-Us          arkouda
# 14   5: Peter Sasha     False       False          dateutil         dateutil
#
#                                                 Title  \
# 1                        SpssParser ignores timezones
# 3   `DeprecationWarning` warning in build log for ...
# 10                             DateTime.add(duration)
# 12          datetime columns in dataframe display bug
# 14                   last day of the month is wrong??
#
#                                                  Link  \
# 1   https://github.com/frictionlessdata/frictionle...
# 3   https://github.com/googleapis/python-storage/i...
# 10   https://github.com/sdispater/pendulum/issues/323
# 12  https://github.com/Bears-R-Us/arkouda/issues/2596
# 14   https://github.com/dateutil/dateutil/issues/1167
#
#                                              Fix Link   Stars   TF-IDFs  ...  \
# 1   https://github.com/frictionlessdata/frictionle...   683.0  1.270077  ...
# 3   https://github.com/googleapis/python-storage/c...   420.0  1.176351  ...
# 10  https://github.com/gridsingularity/gsy-e/pull/...  6109.0  0.996023  ...
# 12  https://github.com/stress-tess/arkouda/commit/...   228.0  0.947325  ...
# 14     https://github.com/dateutil/dateutil/pull/1168  2266.0  0.935691  ...
#
#     Erroneous Computation 1                 Erroneous Computation 2  \
# 1     Datetime Construction  Replacing/Rounding Datetime Components
# 3     Datetime Construction                                     NaN
# 10                      NaN                                     NaN
# 12                      NaN                                     NaN
# 14      Datetime Arithmetic                                     NaN
#
#     Erroneous Computation 3  Obscurity  Impact   # LOC Logic Needed  \
# 1       Library Conversions        Low  Medium  Medium       Medium
# 3                       NaN        Low     Low     Low          Low
# 10                      NaN        NaN     NaN     NaN          NaN
# 12                      NaN        NaN     NaN     NaN          NaN
# 14                      NaN     Medium  Medium  Medium       Medium
#
#                        Bug Pattern 1 Bug Pattern 2 Bug Pattern 3
# 1   Using Naïve Datetime Incorrectly           NaN           NaN
# 3           Outdated/Deprecated APIs           NaN           NaN
# 10                               NaN           NaN           NaN
# 12                               NaN           NaN           NaN
# 14            Unintuitive Arithmetic           NaN           NaN
#
# [5 rows x 26 columns]

# %%
# write it to a file
df.to_csv('./data/bugs_analysis_rater_2.tsv', sep='\t', index=False)
